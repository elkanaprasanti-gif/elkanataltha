# %% [markdown]
# <a href="https://colab.research.google.com/github/elkanaprasanti-gif/elkanataltha/blob/main/2_Tipe_Variabel_Shinta_RH_X_1_Ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("shintahanafiaa.2025@gmail.com")
print("shintahanafiaa.2025@gmail.com")
print("shintahanafiaa.2025@gmail.com")
# Out:
# shintahanafiaa.2025@gmail.com
# shintahanafiaa.2025@gmail.com
# shintahanafiaa.2025@gmail.com

# %%
email_user_1 = "shintahanafiaa.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# shintahanafiaa.2025@gmail.com
# shintahanafiaa.2025@gmail.com
# shintahanafiaa.2025@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
#Sensitif terhadap kapital
email_user_2 = "Keenan Akbar"

print(Email_user_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3731372365.py in <cell line: 0>()
#       1 email_user_2 = "Keenan Akbar"
#       2
# ----> 3 print(Email_user_2)
#
# NameError: name 'Email_user_2' is not defined

# %%
email_user_2 = "Keenan Akbar"

print(email_user_2)
# Out:
# Keenan Akbar

# %%
emailuser2 = "Yoga Armando"

print(emailuser2)
# Out:
# Yoga Armando

# %%
#Hanya boleh menggunakan huruf angka dan underscore
email user 3 = "Dimas Esa"

print(email user 3)
# Out:
#   File "/tmp/ipython-input-234693131.py", line 1
#     email user 3 = "Dimas Esa"
#           ^
# SyntaxError: invalid syntax

# %%
emailUser3 = "Dimas Esa"

print(emailUser3)
# Out:
# Dimas Esa

# %%
#Tidak boleh didahului oleh angka
4_email_user = "Hanafi Naufal"
print(4_email_user)
# Out:
#   File "/tmp/ipython-input-1513168937.py", line 1
#     4_email_user = "Hanafi Naufal"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Tidak boleh menggunakan kata kunci python
for = "Naufal Fajri"

print(for)
# Out:
#   File "/tmp/ipython-input-1274762644.py", line 1
#     for = "Naufal Fajri"
#         ^
# SyntaxError: invalid syntax

# %%
For = "Naufal Fajri"

print(For)
# Out:
# Naufal Fajri

# %%
print = "Alif Nadya"
print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3121028777.py in <cell line: 0>()
#       1 print = "Alif Nadya"
# ----> 2 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Alif Nadya"
print(Print)
# Out:
# Alif Nadya

# %%
_ = "Azka Alifta"

# %%
print(_)
# Out:
# Azka Alifta

# %%
_ = "Kenzo Aliando"

# %%
print(_)
# Out:
# Kenzo Aliando

# %% [markdown]
# #Assignment

# %%
#Single Assignment
beratbadansiswa1 = 90
print(beratbadansiswa1)
# Out:
# 90

# %%
#Multiple assignment
nilai_kka_dias, nilai_kka_azka = 99, 98

print(nilai_kka_azka)
print(nilai_kka_dias)
# Out:
# 98
# 99

# %%
nilai_kka_dias, nilai_kka_azka = 99, 98, 70

print(nilai_kka_azka)
print(nilai_kka_dias)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1966421120.py in <cell line: 0>()
# ----> 1 nilai_kka_dias, nilai_kka_azka = 99, 98, 70
#       2
#       3 print(nilai_kka_azka)
#       4 print(nilai_kka_dias)
#
# ValueError: too many values to unpack (expected 2)

# %%
#Chain assignment
usia_anwar = usia_sahda = 20

print(usia_anwar)
print(usia_sahda)
# Out:
# 20
# 20

# %% [markdown]
# #Cara Penulisan Operasi Aritmatika pada Python

# %%
#Tanpa variabel
print(2+8)
# Out:
# 10

# %%
print("2+8")
# Out:
# 2+8

# %%
print("alhamdulillah")
# Out:
# alhamdulillah

# %%
print(123)
# Out:
# 123

# %%
#Operand disimpan ke variabel
kelereng_dias = 2
kelereng_azka = 8
print(kelereng_dias + kelereng_azka)
# Out:
# 10

# %%
#Hasil operasi disimpan ke variabel
total_kelereng = 8+2
print(total_kelereng)
# Out:
# 10

# %%
#Operand dan hasil operasi disimpan ke variabel
kelereng_azka = 8
kelereng_dias = 2
total_kelereng = kelereng_azka + kelereng_dias
print(total_kelereng)
# Out:
# 10

# %% [markdown]
# #Jenis-jenis operator Aritmatika

# %%
#Penjumlahan
iphone_azka = 5
iphone_anwar = 7

total_iphone = iphone_azka + iphone_anwar
print(total_iphone)
# Out:
# 12

# %%
#Selisih
iphone_azka = 5
iphone_anwar = 7

selisih_iphone =  iphone_anwar - iphone_azka
print(selisih_iphone)
# Out:
# 2

# %%
#Perkalian

type_iphone = "Iphone 16 pro max"
dus_iphone_azka = 3
banyak_iphone_per_dus = 12

total_iphone = dus_iphone_azka * banyak_iphone_per_dus
print(total_iphone)
# Out:
# 36

# %%
#Pembagian
total_iphone = 36
anak_yatim = 7

iphone_per_anak = total_iphone / anak_yatim
print(iphone_per_anak)
# Out:
# 5.142857142857143

# %%
#Pembagian Bulat
total_iphone = 36
anak_yatim = 7

iphone_per_anak = total_iphone // anak_yatim
print(iphone_per_anak)
# Out:
# 5

# %%
#sisa iphone
total_iphone = 36
anak_yatim = 7

sisa_iphone = total_iphone % anak_yatim
print(sisa_iphone)
# Out:
# 1

# %%
sisi = 2
luas_persegi = sisi ** 2

print(luas_persegi)
# Out:
# 4

# %%
sisi = 3

volume = sisi ** 3

print(volume)
# Out:
# 27

# %%
VOLUME_KUBUS = 8
sisi = VOLUME_KUBUS ** (1/3)

print(sisi)
# Out:
# 2.0

# %% [markdown]
# #Jenis-jenis Tipe Variabel

# %%
a = 0
print(a)
type(a)
# Out:
# 0
# int

# %%
b = 0.0
print(b)
type(b)
# Out:
# 0.0
# float

# %%
c = "Hasyim"
print(c)
type(c)
# Out:
# Hasyim
# str

# %%
d = true
print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3721722550.py in <cell line: 0>()
# ----> 1 d = true
#       2 print(d)
#       3 type(d)
#
# NameError: name 'true' is not defined

# %%
d = True
print(d)
type(d)

# %%
e = "False"
print(e)
type(e)
# Out:
# False
# str

# %%
f = 9,9
print(f)
type(f)
# Out:
# (9, 9)
# tuple

# %%
type(8.1)
# Out:
# float

# %% [markdown]
# #Mengubah Tipe Variabel

# %%
x = 8
print(x)
type(x)
# Out:
# 8
# int

# %%
x = float(x)
print(x)
type(x)
# Out:
# 8.0
# float

# %%
z = 10
print(z)
type(z)
# Out:
# 10
# int

# %%
z = float(z)
print(z)
type(z)
# Out:
# 10.0
# float

# %%
k = True
print(k)
type(k)
# Out:
# True
# bool

# %%
k = int(k)
print(k)
type(k)
# Out:
# 1
# int

# %%
m = 2
print(m)
type(m)
# Out:
# 2
# int

# %%
m = bool(m)
print(m)
type(m)
# Out:
# True
# bool

# %%
n = 0.0
print(n)
type(n)
# Out:
# 0.0
# float

# %%
n = bool(n)
print(n)
type(n)
# Out:
# False
# bool

# %%
h = float(5)
print(h)
type(h)
# Out:
# 5.0
# float

# %% [markdown]
# #Operator Perbandingan

# %%
print(5 > 3)
# Out:
# True

# %%
print(5 < 3)
# Out:
# False

# %%
print(5 >= 5)
# Out:
# True

# %%
print(6 >= 5)
# Out:
# True

# %%
print(6 <= 6)
# Out:
# True

# %%
print( 6 != 6 )
# Out:
# False

# %%
print ( 7 == 8)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print( 8 > 7 and 6 == 6 )
# Out:
# True

# %%
print( 5 > 2 or 4 <= 4)
# Out:
# True

# %%
print (not( 5 < 2 or 4 >= 4 ))
# Out:
# False

# %%
a = 10
b = 20
c = 30

print(not(a > b and a != c))
# Out:
# True

# %%
print( not( 10 == a or c <= 31 ))
# Out:
# False

# %%
nilai_kka = 76
kkm_kka = 75

print(nilai_kka >= kkm_kka)
# Out:
# True
